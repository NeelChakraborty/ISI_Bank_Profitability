# %%
import convert_to_csv

file_read = open('Dataset/Bank Data/1999_2002_1.txt', 'r')
csv = convert_to_csv.convert(file_read)
file_write = open('Dataset/Bank Data/1999_2002_1.csv', 'w')
file_write.write(csv)
# Out:
# 3532

# %%
#Don't run more than once
import pandas as pd

data_1999_2002 = pd.read_csv('Dataset/Bank Data/1999_2002_1.csv', index_col=0, names=[1999, 2000, 2001, 2002,
                                                                                      1999, 2000, 2001, 2002,
                                                                                      1999, 2000, 2001, 2002])
data_1999_2002
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>1999</th>
#       <th>2000</th>
#       <th>2001</th>
#       <th>2002</th>
#       <th>1999.1</th>
#       <th>2000.1</th>
#       <th>2001.1</th>
#       <th>2002.1</th>
#       <th>1999.2</th>
#       <th>2000.2</th>
#       <th>2001.2</th>
#       <th>2002.2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Cashdeposit_ratio</th>
#       <td>10.29</td>
#       <td>9.60</td>
#       <td>7.62</td>
#       <td>8.08</td>
#       <td>16.31</td>
#       <td>13.76</td>
#       <td>12.99</td>
#       <td>7.79</td>
#       <td>10.91</td>
#       <td>10.96</td>
#       <td>7.31</td>
#       <td>7.54</td>
#     </tr>
#     <tr>
#       <th>Creditdeposit_ratio</th>
#       <td>48.72</td>
#       <td>49.84</td>
#       <td>46.78</td>
#       <td>44.65</td>
#       <td>49.62</td>
#       <td>48.50</td>
#       <td>50.05</td>
#       <td>50.86</td>
# ...

# %%
data_1999_2002.to_csv('Dataset/Bank Data/1999_2002_1.csv')

# %%
data_1999_2002_sbi = data_1999_2002[[1999, 2000, 2001, 2002]]
# %store data_1999_2002_sbi
data_1999_2002_sbi
# Out:
# Stored 'data_1999_2002_sbi' (DataFrame)
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>1999</th>
#       <th>2000</th>
#       <th>2001</th>
#       <th>2002</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Cashdeposit_ratio</th>
#       <td>10.29</td>
#       <td>9.60</td>
#       <td>7.62</td>
#       <td>8.08</td>
#     </tr>
#     <tr>
#       <th>Creditdeposit_ratio</th>
#       <td>48.72</td>
#       <td>49.84</td>
#       <td>46.78</td>
#       <td>44.65</td>
#     </tr>
#     <tr>
#       <th>Investmentdeposit_ratio</th>
#       <td>42.17</td>
#       <td>46.68</td>
#       <td>50.60</td>
#       <td>53.65</td>
#     </tr>
#     <tr>
#       <th>(Credit_+ investment)deposit_ratio</th>
#       <td>90.89</td>
#       <td>96.52</td>
#       <td>97.38</td>
#       <td>98.30</td>
#     </tr>
#     <tr>
#       <th>Ratio_of_deposits_to_total_liabilities</th>
#       <td>75.97</td>
# ...

# %%
data_1999_2002_sbi.to_csv('Dataset/Bank Data/1999_2002_1_sbi.csv')

# %%
# %store -r data_1999_2002_sbi
data_1999_2002_sbi
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>1999</th>
#       <th>2000</th>
#       <th>2001</th>
#       <th>2002</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Cashdeposit_ratio</th>
#       <td>10.29</td>
#       <td>9.60</td>
#       <td>7.62</td>
#       <td>8.08</td>
#     </tr>
#     <tr>
#       <th>Creditdeposit_ratio</th>
#       <td>48.72</td>
#       <td>49.84</td>
#       <td>46.78</td>
#       <td>44.65</td>
#     </tr>
#     <tr>
#       <th>Investmentdeposit_ratio</th>
#       <td>42.17</td>
#       <td>46.68</td>
#       <td>50.60</td>
#       <td>53.65</td>
#     </tr>
#     <tr>
#       <th>(Credit_+ investment)deposit_ratio</th>
#       <td>90.89</td>
#       <td>96.52</td>
#       <td>97.38</td>
#       <td>98.30</td>
#     </tr>
#     <tr>
#       <th>Ratio_of_deposits_to_total_liabilities</th>
#       <td>75.97</td>
#       <td>75.26</td>
#       <td>76.93</td>
# ...

# %%
import convert_to_csv

file_read = open('Dataset/Bank Data/2003_2004_1.txt', 'r')
csv = convert_to_csv.convert(file_read)
file_write = open('Dataset/Bank Data/2003_2004_1.csv', 'w')
file_write.write(csv)
# Out:
# 2802

# %%
#Don't run more than once
import pandas as pd

data_2003_2004 = pd.read_csv('Dataset/Bank Data/2003_2004_1.csv', index_col=0, names=[2003, 2004,
                                                                                      2003, 2004,
                                                                                      2003, 2004,
                                                                                      2003, 2004])
data_2003_2004

# %%
data_2003_2004.to_csv('Dataset/Bank Data/2003_2004_1.csv')

# %%
data_2003_2004_sbi = data_2003_2004[[2003, 2004]]
# %store data_2003_2004_sbi
data_2003_2004_sbi
# Out:
# Stored 'data_2003_2004_sbi' (DataFrame)
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>2003</th>
#       <th>2004</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Cashdeposit_ratio</th>
#       <td>4.30</td>
#       <td>5.98</td>
#     </tr>
#     <tr>
#       <th>Creditdeposit_ratio</th>
#       <td>46.52</td>
#       <td>49.57</td>
#     </tr>
#     <tr>
#       <th>Investmentdeposit_ratio</th>
#       <td>58.20</td>
#       <td>58.28</td>
#     </tr>
#     <tr>
#       <th>(Credit+_Investment)deposit_ratio</th>
#       <td>104.72</td>
#       <td>107.84</td>
#     </tr>
#     <tr>
#       <th>Ratio_of_deposits_to_total_liabilities</th>
#       <td>78.78</td>
#       <td>78.13</td>
#     </tr>
#     <tr>
#       <th>Ratio_of_term_deposits_to_total_deposits</th>
#       <td>62.67</td>
#       <td>59.23</td>
#     </tr>
#     <tr>
# ...

# %%
data_2003_2004_sbi.to_csv('Dataset/Bank Data/2003_2004_1_sbi.csv')

# %%
file_read = open('Dataset/Bank Data/2005_2006_1.txt', 'r')
csv = convert_to_csv.convert(file_read)
file_write = open('Dataset/Bank Data/2005_2006_1.csv', 'w')
file_write.write(csv)
# Out:
# 2776

# %%
data_2005_2006 = pd.read_csv('Dataset/Bank Data/2005_2006_1.csv', index_col=0, names=[2005, 2006,
                                                                                      2005, 2006,
                                                                                      2005, 2006,
                                                                                      2005, 2006])
data_2005_2006

# %%
data_2005_2006.to_csv('Dataset/Bank Data/2005_2006_1.csv')

# %%
data_2005_2006_sbi.to_csv('Dataset/Bank Data/2005_2006_1_sbi.csv')

# %%
data_2005_2006_sbi = data_2005_2006[[2005, 2006]]
# %store data_2005_2006_sbi
data_2005_2006_sbi
# Out:
# Stored 'data_2005_2006_sbi' (DataFrame)
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>2005</th>
#       <th>2006</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Cashdeposit_ratio</th>
#       <td>4.58</td>
#       <td>5.70</td>
#     </tr>
#     <tr>
#       <th>Creditdeposit_ratio</th>
#       <td>55.14</td>
#       <td>68.84</td>
#     </tr>
#     <tr>
#       <th>Investmentdeposit_ratio</th>
#       <td>53.70</td>
#       <td>42.77</td>
#     </tr>
#     <tr>
#       <th>(Credit_+ Investment)_deposit_ratio</th>
#       <td>108.83</td>
#       <td>111.61</td>
#     </tr>
#     <tr>
#       <th>Ratio_of_deposits_to_total_liabilities</th>
#       <td>79.81</td>
#       <td>76.95</td>
#     </tr>
#     <tr>
#       <th>Ratio_of_term_deposits_to_total_deposits</th>
#       <td>58.72</td>
#       <td>52.45</td>
#     </tr>
#     <tr>
# ...

# %%
data_2005_2006_sbi.to_csv('Dataset/Bank Data/2005_2006_1_sbi.csv')

# %%
file_read = open('Dataset/Bank Data/2007_2009_1.txt', 'r')
csv = convert_to_csv.convert(file_read)
file_write = open('Dataset/Bank Data/2007_2009_1.csv', 'w')
file_write.write(csv)
# Out:
# 3519

# %%
data_2007_2009 = pd.read_csv('Dataset/Bank Data/2007_2009_1.csv', index_col=0, names=[2007, 2008, 2009,
                                                                                      2007, 2008, 2009,
                                                                                      2007, 2008, 2009,
                                                                                      2007, 2008, 2009])
data_2007_2009
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>2007</th>
#       <th>2008</th>
#       <th>2009</th>
#       <th>2007.1</th>
#       <th>2008.1</th>
#       <th>2009.1</th>
#       <th>2007.2</th>
#       <th>2008.2</th>
#       <th>2009.2</th>
#       <th>2007.3</th>
#       <th>2008.3</th>
#       <th>2009.3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Cashdeposit_ratio</th>
#       <td>6.68</td>
#       <td>9.59</td>
#       <td>7.49</td>
#       <td>12.83</td>
#       <td>11.46</td>
#       <td>9.17</td>
#       <td>6.92</td>
#       <td>11.07</td>
#       <td>8.69</td>
#       <td>6.71</td>
#       <td>6.80</td>
#       <td>6.18</td>
#     </tr>
#     <tr>
#       <th>Creditdeposit_ratio</th>
#       <td>77.50</td>
#       <td>77.55</td>
#       <td>73.11</td>
#       <td>72.07</td>
#       <td>73.52</td>
#       <td>76.10</td>
#       <td>67.73</td>
#       <td>71.54</td>
# ...

# %%
data_2007_2009.to_csv('Dataset/Bank Data/2007_2009_1.csv')

# %%
data_2007_2009_sbi = data_2007_2009[[2007, 2008, 2009]]
# %store data_2007_2009_sbi
data_2007_2009_sbi
# Out:
# Stored 'data_2007_2009_sbi' (DataFrame)
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>2007</th>
#       <th>2008</th>
#       <th>2009</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Cashdeposit_ratio</th>
#       <td>6.68</td>
#       <td>9.59</td>
#       <td>7.49</td>
#     </tr>
#     <tr>
#       <th>Creditdeposit_ratio</th>
#       <td>77.50</td>
#       <td>77.55</td>
#       <td>73.11</td>
#     </tr>
#     <tr>
#       <th>Investmentdeposit_ratio</th>
#       <td>34.30</td>
#       <td>35.26</td>
#       <td>37.19</td>
#     </tr>
#     <tr>
#       <th>(Credit_+ Investment)_deposit_ratio</th>
#       <td>112.00</td>
#       <td>112.81</td>
#       <td>110.29</td>
#     </tr>
#     <tr>
#       <th>Ratio_of_deposits_to_total_liabilities</th>
#       <td>76.90</td>
#       <td>74.48</td>
#       <td>76.94</td>
#     </tr>
#     <tr>
# ...

# %%
data_2007_2009_sbi.to_csv('Dataset/Bank Data/2007_2009_1_sbi.csv')
len(data_1999_2002_sbi)

# %%
data_1999_2002_sbi = pd.read_csv('Dataset/Bank Data/1999_2002_1_sbi.csv', index_col=0)
# %store data_1999_2002_sbi 
data_2003_2004_sbi = pd.read_csv('Dataset/Bank Data/2003_2004_1_sbi.csv', index_col=0)
# %store data_2003_2004_sbi
data_2005_2006_sbi = pd.read_csv('Dataset/Bank Data/2005_2006_1_sbi.csv', index_col=0)
# %store data_2005_2006_sbi
data_2007_2009_sbi = pd.read_csv('Dataset/Bank Data/2007_2009_1_sbi.csv', index_col=0)
# %store data_2007_2009_sbi
# Out:
# Stored 'data_1999_2002_sbi' (DataFrame)
# Stored 'data_2003_2004_sbi' (DataFrame)
# Stored 'data_2005_2006_sbi' (DataFrame)
# Stored 'data_2007_2009_sbi' (DataFrame)

# %%
print(len(data_1999_2002_sbi), len(data_2003_2004_sbi), len(data_2005_2006_sbi), len(data_2007_2009_sbi))
# Out:
# 35 35 35 35

# %%
import pandas as pd
# %store -r data_1999_2002_sbi
# %store -r data_2003_2004_sbi
# %store -r data_2005_2006_sbi
# %store -r data_2007_2009_sbi
data_1999_2009_sbi = pd.concat([data_1999_2002_sbi.rename(index=str.lower),
                                data_2003_2004_sbi.rename(index=str.lower),
                                data_2005_2006_sbi.rename(index=str.lower),
                                data_2007_2009_sbi.rename(index=str.lower)], axis=1)
data_1999_2009_sbi.to_csv('Dataset/Bank Data/1999_2009_sbi.csv')

# %%
import pandas as pd

data_1999_2009_sbi = pd.read_csv('Dataset/Bank Data/1999_2009_sbi.csv')
# %store data_1999_2009_sbi
# Out:
# Stored 'data_1999_2009_sbi' (DataFrame)

# %%
import convert_to_csv

file_read = open('Dataset/Bank Data/NPA_1996_2000.txt', 'r')
csv = convert_to_csv.convert(file_read)
file_write = open('Dataset/Bank Data/NPA_1996_2000.csv', 'w')
file_write.write(csv)
# Out:
# 1768

# %%
data_NPA_1996_2000 = pd.read_csv('Dataset/Bank Data/NPA_1996_2000.csv', index_col=0, names=[1997, 1998, 1999, 2000,
                                                                                            1997, 1998, 1999, 2000])
# %store data_NPA_1996_2000
data_NPA_1996_2000.to_csv('Dataset/Bank Data/NPA_1996_2000.csv')
# Out:
# Stored 'data_NPA_1996_2000' (DataFrame)

# %%
data_NPA_1996_2000_sbi = data_NPA_1996_2000.loc['State_Bank_of_India', [1999, 2000, '1999.1', '2000.1']]
data_NPA_1996_2000_sbi
data_NPA_1996_2000_sbi
# Out:
# Stored 'data_NPA_1996_2000_sbi' (Series)
# 1999      6.32
# 2000      5.83
# 1999.1    2.65
# 2000.1    2.40
# Name: State_Bank_of_India, dtype: float64

# %%
from numpy import reshape
data_NPA_1996_2000_sbi = pd.DataFrame(data_NPA_1996_2000_sbi.values.reshape(2, 2), 
                                      columns=[1999, 2000], 
                                      index=['Gross NPAs/Total Assets', 'Net NPAs/Total Assets'])
data_NPA_1996_2000_sbi
# %store data_NPA_1996_2000_sbi
data_NPA_1996_2000_sbi.to_csv('Dataset/Bank Data/NPA_1996_2000_sbi.csv')
# Out:
# Stored 'data_NPA_1996_2000_sbi' (DataFrame)

# %%
file_read = open('Dataset/Bank Data/NPA_2000_2006.txt', 'r')
csv = convert_to_csv.convert(file_read)
file_write = open('Dataset/Bank Data/NPA_2000_2006.csv', 'w')
file_write.write(csv)
# Out:
# 2469

# %%
data_NPA_2000_2006 = pd.read_csv('Dataset/Bank Data/NPA_2000_2006.csv', index_col=0,
                                     names=[2001, 2002, 2003, 2004, 2005, 2006,
                                            2001, 2002, 2003, 2004, 2005, 2006])
# %store data_NPA_2000_2006
data_NPA_2000_2006.to_csv('Dataset/Bank Data/NPA_2000_2006.csv')
data_NPA_2000_2006
# Out:
# Stored 'data_NPA_2000_2006' (DataFrame)
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>2001</th>
#       <th>2002</th>
#       <th>2003</th>
#       <th>2004</th>
#       <th>2005</th>
#       <th>2006</th>
#       <th>2001.1</th>
#       <th>2002.1</th>
#       <th>2003.1</th>
#       <th>2004.1</th>
#       <th>2005.1</th>
#       <th>2006.1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Allahabad_Bank</th>
#       <td>8.26</td>
#       <td>8.08</td>
#       <td>6.56</td>
#       <td>4.09</td>
#       <td>2.84</td>
#       <td>2.14</td>
#       <td>4.87</td>
#       <td>4.68</td>
#       <td>3.16</td>
#       <td>1.05</td>
#       <td>0.60</td>
#       <td>0.45</td>
#     </tr>
#     <tr>
#       <th>Andhra_Bank</th>
#       <td>2.31</td>
#       <td>2.50</td>
#       <td>2.35</td>
#       <td>2.28</td>
#       <td>1.35</td>
#       <td>1.07</td>
#       <td>1.07</td>
# ...

# %%
data_NPA_2000_2006_sbi = data_NPA_2000_2006.loc['State_Bank_of_India', 
                                                [2001, 2002, 2003, 2004, 2005, 2006, 
                                                 '2001.1', '2002.1', '2003.1', '2004.1', '2005.1', '2006.1']]
data_NPA_2000_2006_sbi
# Out:
# 2001      5.03
# 2002      4.45
# 2003      3.59
# 2004      3.11
# 2005      2.71
# 2006      2.10
# 2001.1    2.17
# 2002.1    1.96
# 2003.1    1.64
# 2004.1    1.33
# 2005.1    1.16
# 2006.1    0.99
# Name: State_Bank_of_India, dtype: float64

# %%
data_NPA_2000_2006_sbi = pd.DataFrame(data_NPA_2000_2006_sbi.values.reshape(2, 6),
                                      columns=[2001, 2002, 2003, 2004, 2005, 2006],
                                      index=['Gross NPAs/Total Assets', 'Net NPAs/Total Assets'])
data_NPA_2000_2006_sbi
# %store data_NPA_2000_2006_sbi
data_NPA_2000_2006_sbi.to_csv('Dataset/Bank Data/NPA_2000_2006_sbi.csv')
# Out:
# Stored 'data_NPA_2000_2006_sbi' (DataFrame)

# %%
file_read = open('Dataset/Bank Data/NPA_2006_2009.txt', 'r')
csv = convert_to_csv.convert(file_read)
file_write = open('Dataset/Bank Data/NPA_2006_2009.csv', 'w')
file_write.write(csv)
# Out:
# 1384

# %%
data_NPA_2006_2009 = pd.read_csv('Dataset/Bank Data/NPA_2006_2009.csv', index_col=0,
                                     names=[2007, 2008, 2009,
                                            2007, 2008, 2009])
# %store data_NPA_2006_2009
data_NPA_2006_2009.to_csv('Dataset/Bank Data/NPA_2006_2009.csv')
data_NPA_2006_2009
# Out:
# Stored 'data_NPA_2006_2009' (DataFrame)
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>2007</th>
#       <th>2008</th>
#       <th>2009</th>
#       <th>2007.1</th>
#       <th>2008.1</th>
#       <th>2009.1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Scheduled_Commercial_Banks</th>
#       <td>1.5</td>
#       <td>1.3</td>
#       <td>1.3</td>
#       <td>0.6</td>
#       <td>0.6</td>
#       <td>0.6</td>
#     </tr>
#     <tr>
#       <th>Public_Sector_Banks</th>
#       <td>1.6</td>
#       <td>1.3</td>
#       <td>1.2</td>
#       <td>0.6</td>
#       <td>0.6</td>
#       <td>0.6</td>
#     </tr>
#     <tr>
#       <th>Nationalised_Banks</th>
#       <td>1.6</td>
#       <td>1.3</td>
#       <td>1.1</td>
#       <td>0.5</td>
#       <td>0.4</td>
#       <td>0.4</td>
#     </tr>
#     <tr>
#       <th>Allahabad_Bank</th>
#       <td>1.6</td>
#       <td>1.2</td>
# ...

# %%
data_NPA_2006_2009_sbi = data_NPA_2006_2009.loc['State_Bank_of_India', 
                                                [2007, 2008, 2009, 
                                                 '2007.1', '2008.1', '2009.1']]
data_NPA_2006_2009_sbi
# Out:
# 2007      1.8
# 2008      1.8
# 2009      1.6
# 2007.1    0.9
# 2008.1    1.0
# 2009.1    1.0
# Name: State_Bank_of_India, dtype: float64

# %%
data_NPA_2006_2009_sbi = pd.DataFrame(data_NPA_2006_2009_sbi.values.reshape(2, 3),
                                      columns=[2007, 2008, 2009],
                                      index=['Gross NPAs/Total Assets', 'Net NPAs/Total Assets'])
data_NPA_2006_2009_sbi
# %store data_NPA_2006_2009_sbi
data_NPA_2006_2009_sbi.to_csv('Dataset/Bank Data/NPA_2006_2009_sbi.csv')
# Out:
# Stored 'data_NPA_2006_2009_sbi' (DataFrame)

# %%
data_NPA_1999_2009_sbi = pd.concat([data_NPA_1996_2000_sbi.rename(index=str.lower), 
                                   data_NPA_2000_2006_sbi.rename(index=str.lower),
                                   data_NPA_2006_2009_sbi.rename(index=str.lower)], axis=1)
# %store data_NPA_1999_2009_sbi 
data_NPA_1999_2009_sbi.to_csv('Dataset/Bank Data/NPA_1999_2009_sbi.csv')
# Out:
# Stored 'data_NPA_1999_2009_sbi' (DataFrame)

# %%
data_1999_2009_sbi = pd.read_csv('Dataset/Bank Data/1999_2009_sbi.csv', index_col=0)
data_1999_2009_sbi
# %store data_1999_2009_sbi
# Out:
# Stored 'data_1999_2009_sbi' (DataFrame)

# %%
# %store -r data_1999_2009_sbi

# %%
data_1999_2009_sbi.columns = pd.to_numeric(data_1999_2009_sbi.columns)
data_1999_2009_sbi.columns
# Out:
# Int64Index([1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009], dtype='int64')

# %%
# %store -r data_1999_2009_sbi
data_1999_2009_sbi = pd.concat([data_1999_2009_sbi, data_NPA_1999_2009_sbi])
data_1999_2009_sbi
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>1999</th>
#       <th>2000</th>
#       <th>2001</th>
#       <th>2002</th>
#       <th>2003</th>
#       <th>2004</th>
#       <th>2005</th>
#       <th>2006</th>
#       <th>2007</th>
#       <th>2008</th>
#       <th>2009</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>(credit_+ investment)deposit_ratio</th>
#       <td>90.89</td>
#       <td>96.52</td>
#       <td>97.38</td>
#       <td>98.30</td>
#       <td>104.72</td>
#       <td>107.84</td>
#       <td>108.83</td>
#       <td>111.61</td>
#       <td>112.00</td>
#       <td>112.81</td>
#       <td>110.29</td>
#     </tr>
#     <tr>
#       <th>business_per_employee_(in_rs._lakh)</th>
#       <td>93.64</td>
#       <td>111.20</td>
#       <td>136.58</td>
#       <td>173.01</td>
#       <td>191.00</td>
#       <td>210.56</td>
#       <td>243.08</td>
#       <td>299.23</td>
# ...

# %%
# %store data_1999_2009_sbi
# Out:
# Stored 'data_1999_2009_sbi' (DataFrame)

# %%
data_1999_2009_sbi.to_csv('Dataset/Bank Data/1999_2009_sbi.csv')
