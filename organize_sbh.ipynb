# %%
#Don't run more than once
import pandas as pd

data_1999_2002 = pd.read_csv('Dataset/Bank Data/1999_2002_1.csv', index_col=0, names=[1999, 2000, 2001, 2002,
                                                                                      1999, 2000, 2001, 2002,
                                                                                      1999, 2000, 2001, 2002])
data_1999_2002
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>1999</th>
#       <th>2000</th>
#       <th>2001</th>
#       <th>2002</th>
#       <th>1999.1</th>
#       <th>2000.1</th>
#       <th>2001.1</th>
#       <th>2002.1</th>
#       <th>1999.2</th>
#       <th>2000.2</th>
#       <th>2001.2</th>
#       <th>2002.2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Cashdeposit_ratio</th>
#       <td>10.29</td>
#       <td>9.60</td>
#       <td>7.62</td>
#       <td>8.08</td>
#       <td>16.31</td>
#       <td>13.76</td>
#       <td>12.99</td>
#       <td>7.79</td>
#       <td>10.91</td>
#       <td>10.96</td>
#       <td>7.31</td>
#       <td>7.54</td>
#     </tr>
#     <tr>
#       <th>Creditdeposit_ratio</th>
#       <td>48.72</td>
#       <td>49.84</td>
#       <td>46.78</td>
#       <td>44.65</td>
#       <td>49.62</td>
#       <td>48.50</td>
#       <td>50.05</td>
#       <td>50.86</td>
# ...

# %%
data_1999_2002_sbh = data_1999_2002[['1999.2', '2000.2', '2001.2', '2002.2']]
# %store data_1999_2002_sbh
data_1999_2002_sbh
# Out:
# Stored 'data_1999_2002_sbh' (DataFrame)
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>1999.2</th>
#       <th>2000.2</th>
#       <th>2001.2</th>
#       <th>2002.2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Cashdeposit_ratio</th>
#       <td>10.91</td>
#       <td>10.96</td>
#       <td>7.31</td>
#       <td>7.54</td>
#     </tr>
#     <tr>
#       <th>Creditdeposit_ratio</th>
#       <td>50.23</td>
#       <td>48.60</td>
#       <td>47.78</td>
#       <td>48.40</td>
#     </tr>
#     <tr>
#       <th>Investmentdeposit_ratio</th>
#       <td>55.68</td>
#       <td>55.96</td>
#       <td>59.01</td>
#       <td>56.47</td>
#     </tr>
#     <tr>
#       <th>(Credit_+ investment)deposit_ratio</th>
#       <td>105.92</td>
#       <td>104.56</td>
#       <td>106.79</td>
#       <td>104.87</td>
#     </tr>
#     <tr>
#       <th>Ratio_of_deposits_to_total_liabilities</th>
# ...

# %%
data_2003_2004 = pd.read_csv('Dataset/Bank Data/2003_2004_1.csv', index_col=0)
data_2003_2004
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>2003</th>
#       <th>2004</th>
#       <th>2003.1</th>
#       <th>2004.1</th>
#       <th>2003.2</th>
#       <th>2004.2</th>
#       <th>2003.3</th>
#       <th>2004.3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Cashdeposit_ratio</th>
#       <td>4.30</td>
#       <td>5.98</td>
#       <td>6.64</td>
#       <td>8.06</td>
#       <td>8.87</td>
#       <td>7.50</td>
#       <td>6.76</td>
#       <td>5.30</td>
#     </tr>
#     <tr>
#       <th>Creditdeposit_ratio</th>
#       <td>46.52</td>
#       <td>49.57</td>
#       <td>51.18</td>
#       <td>54.96</td>
#       <td>46.91</td>
#       <td>48.70</td>
#       <td>56.23</td>
#       <td>61.49</td>
#     </tr>
#     <tr>
#       <th>Investmentdeposit_ratio</th>
#       <td>58.20</td>
#       <td>58.28</td>
#       <td>58.05</td>
#       <td>53.89</td>
#       <td>60.77</td>
# ...

# %%
data_2003_2004_sbh = data_2003_2004[['2003.2', '2004.2']]
# %store data_2003_2004_sbh
data_2003_2004_sbh
# Out:
# Stored 'data_2005_2006_sbh' (DataFrame)
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>2005.2</th>
#       <th>2006.2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Cashdeposit_ratio</th>
#       <td>4.81</td>
#       <td>6.69</td>
#     </tr>
#     <tr>
#       <th>Creditdeposit_ratio</th>
#       <td>53.92</td>
#       <td>61.32</td>
#     </tr>
#     <tr>
#       <th>Investmentdeposit_ratio</th>
#       <td>50.33</td>
#       <td>41.90</td>
#     </tr>
#     <tr>
#       <th>(Credit_+ Investment)_deposit_ratio</th>
#       <td>104.25</td>
#       <td>103.22</td>
#     </tr>
#     <tr>
#       <th>Ratio_of_deposits_to_total_liabilities</th>
#       <td>82.84</td>
#       <td>83.74</td>
#     </tr>
#     <tr>
#       <th>Ratio_of_term_deposits_to_total_deposits</th>
#       <td>67.37</td>
#       <td>65.66</td>
#     </tr>
#     <tr>
# ...

# %%
data_2005_2006 = pd.read_csv('Dataset/Bank Data/2005_2006_1.csv', index_col=0)
data_2005_2006

data_2005_2006_sbh = data_2005_2006[['2005.2', '2006.2']]
# %store data_2005_2006_sbh
data_2005_2006_sbh
# Out:
# Stored 'data_2005_2006_sbh' (DataFrame)
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>
data_NPA_1996_2000.to_csv('Dataset/Bank Data/NPA_1996_2000.csv')

# %%
data_NPA_1996_2000_sbh = data_NPA_1996_2000.loc['State_Bank_of_Hyderabad', [1999, 2000, '1999.1', '2000.1']]
data_NPA_1996_2000_sbh
data_NPA_1996_2000_sbh
# Out:
# 1999      7.00
# 2000      6.03
# 1999.1    3.55
# 2000.1    2.86
# Name: State_Bank_of_Hyderabad, dtype: float64

# %%
data_NPA_1996_2000_sbh = pd.DataFrame(data_NPA_1996_2000_sbh.values.reshape(2, 2), 
                                      columns=[1999, 2000], 
                                      index=['Gross NPAs/Total Assets', 'Net NPAs/Total Assets'])
data_NPA_1996_2000_sbh
# %store data_NPA_1996_2000_sbh
data_NPA_1996_2000_sbh.to_csv('Dataset/Bank Data/NPA_1996_2000_sbh.csv')
# Out:
# Stored 'data_NPA_1996_2000_sbh' (DataFrame)

# %%
data_NPA_2000_2006 = pd.read_csv('Dataset/Bank Data/NPA_2000_2006.csv', index_col=0)
data_NPA_2000_2006
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>2001</th>
#       <th>2002</th>
#       <th>2003</th>
#       <th>2004</th>
#       <th>2005</th>
#       <th>2006</th>
#       <th>2001.1</th>
#       <th>2002.1</th>
#       <th>2003.1</th>
#       <th>2004.1</th>
#       <th>2005.1</th>
#       <th>2006.1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Allahabad_Bank</th>
#       <td>8.26</td>
#       <td>8.08</td>
#       <td>6.56</td>
#       <td>4.09</td>
#       <td>2.84</td>
#       <td>2.14</td>
#       <td>4.87</td>
#       <td>4.68</td>
#       <td>3.16</td>
#       <td>1.05</td>
#       <td>0.60</td>
#       <td>0.45</td>
#     </tr>
#     <tr>
#       <th>Andhra_Bank</th>
#       <td>2.31</td>
#       <td>2.50</td>
#       <td>2.35</td>
#       <td>2.28</td>
#       <td>1.35</td>
#       <td>1.07</td>
#       <td>1.07</td>
#       <td>1.13</td>
#       <td>0.84</td>
# ...

# %%
data_NPA_2000_2006_sbh = data_NPA_2000_2006.loc['State_Bank_of_Hyderabad', 
                                                ['2001', '2002', '2003', '2004', '2005', '2006', 
                                                 '2001.1', '2002.1', '2003.1', '2004.1', '2005.1', '2006.1']]
data_NPA_2000_2006_sbh
# Out:
# 2001      5.84
# 2002      4.06
# 2003      2.83
# 2004      2.26
# 2005      1.58
# 2006      1.12
# 2001.1    3.01
# 2002.1    1.89
# 2003.1    1.21
# 2004.1    0.25
# 2005.1    0.27
# 2006.1    0.19
# Name: State_Bank_of_Hyderabad, dtype: float64

# %%
data_NPA_2000_2006_sbh = pd.DataFrame(data_NPA_2000_2006_sbh.values.reshape(2, 6),
                                      columns=[2001, 2002, 2003, 2004, 2005, 2006],
                                      index=['Gross NPAs/Total Assets', 'Net NPAs/Total Assets'])
data_NPA_2000_2006_sbh
# %store data_NPA_2000_2006_sbh
data_NPA_2000_2006_sbh.to_csv('Dataset/Bank Data/NPA_2006_2009_sbh.csv')
# Out:
# Stored 'data_NPA_2000_2006_sbh' (DataFrame)

# %%
data_NPA_2000_2006_sbh
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>2001</th>
#       <th>2002</th>
#       <th>2003</th>
#       <th>2004</th>
#       <th>2005</th>
#       <th>2006</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Gross NPAs/Total Assets</th>
#       <td>5.84</td>
#       <td>4.06</td>
#       <td>2.83</td>
#       <td>2.26</td>
#       <td>1.58</td>
#       <td>1.12</td>
#     </tr>
#     <tr>
#       <th>Net NPAs/Total Assets</th>
#       <td>3.01</td>
#       <td>1.89</td>
#       <td>1.21</td>
#       <td>0.25</td>
#       <td>0.27</td>
#       <td>0.19</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
data_NPA_2006_2009 = pd.read_csv('Dataset/Bank Data/NPA_2006_2009.csv', index_col=0, names=[2007, 2008, 2009,
                                            2007, 2008, 2009])
data_NPA_2006_2009
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>2007</th>
#       <th>2008</th>
#       <th>2009</th>
#       <th>2007.1</th>
#       <th>2008.1</th>
#       <th>2009.1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Scheduled_Commercial_Banks</th>
#       <td>1.5</td>
#       <td>1.3</td>
#       <td>1.3</td>
#       <td>0.6</td>
#       <td>0.6</td>
#       <td>0.6</td>
#     </tr>
#     <tr>
#       <th>Public_Sector_Banks</th>
#       <td>1.6</td>
#       <td>1.3</td>
#       <td>1.2</td>
#       <td>0.6</td>
#       <td>0.6</td>
#       <td>0.6</td>
#     </tr>
#     <tr>
#       <th>Nationalised_Banks</th>
#       <td>1.6</td>
#       <td>1.3</td>
#       <td>1.1</td>
#       <td>0.5</td>
#       <td>0.4</td>
#       <td>0.4</td>
#     </tr>
#     <tr>
#       <th>Allahabad_Bank</th>
#       <td>1.6</td>
#       <td>1.2</td>
#       <td>1.1</td>
#       <td>0.7</td>
# ...

# %%
data_NPA_2006_2009_sbh = data_NPA_2006_2009.loc['State_Bank_of_Hyderabad', 
                                                [2007, 2008, 2009, 
                                                 '2007.1', '2008.1', '2009.1']]
data_NPA_2006_2009_sbh
# Out:
# 2007      0.7
# 2008      0.5
# 2009      0.6
# 2007.1    0.1
# 2008.1    0.1
# 2009.1    0.2
# Name: State_Bank_of_Hyderabad, dtype: object

# %%
data_NPA_2006_2009_sbh = pd.DataFrame(data_NPA_2006_2009_sbh.values.reshape(2, 3),
                                      columns=[2007, 2008, 2009],
                                      index=['Gross NPAs/Total Assets', 'Net NPAs/Total Assets'])
data_NPA_2006_2009_sbh
# %store data_NPA_2006_2009_sbh
data_NPA_2006_2009_sbh.to_csv('Dataset/Bank Data/NPA_2006_2009_sbh.csv')
# Out:
# Stored 'data_NPA_2006_2009_sbh' (DataFrame)

# %%
data_1999_2009_sbh = pd.concat([data_1999_2002_sbh.rename(index=str.lower),
                                data_2003_2004_sbh.rename(index=str.lower),
                                data_2005_2006_sbh.rename(index=str.lower),
                                data_2005_2006_sbh.rename(index=str.lower)], axis=1)
% store data_1999_2009_sbh
data_1999_2009_sbh.to_csv('Dataset/Bank Data/NPA_1999_2009_sbh.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-9a54499e2f8e> in <module>()
#       2                                 data_2003_2004_sbh.rename(index=str.lower),
#       3                                 data_2005_2006_sbh.rename(index=str.lower),
# ----> 4                                 data_2005_2006_sbh.rename(index=str.lower)], axis=1)
#       5 get_ipython().magic('store data_1999_2009_sbh')
#       6 data_1999_2009_sbh.to_csv('Dataset/Bank Data/NPA_1999_2009_sbh.csv')
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\tools\merge.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#    1450                        verify_integrity=verify_integrity,
#    1451                        copy=copy)
# -> 1452     return op.get_result()
#    1453
#    1454
#
# ...

# %%
data_1999_2002 = pd.read_csv('Dataset/Bank Data/1999_2002_1.csv', index_col=0, names=[1999, 2000, 2001, 2002,
                                                                                      1999, 2000, 2001, 2002,
                                                                                      1999, 2000, 2001, 2002])
data_1999_2002.to_csv('Dataset/Bank Data/1999_2002_1.csv')
