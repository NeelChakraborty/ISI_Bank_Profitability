# %%
import pandas as pd

data_1999_2009_sbi = pd.read_csv('Dataset/Bank Data/SBI/1999_2009_sbi.csv', index_col=1)
data_1999_2009_sbi.drop('Unnamed: 0', axis=1, inplace=True)
# %store data_1999_2009_sbi
data_1999_2009_sbi
# Out:
# Stored 'data_1999_2009_sbi' (DataFrame)
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>1999</th>
#       <th>2000</th>
#       <th>2001</th>
#       <th>2002</th>
#       <th>2003</th>
#       <th>2004</th>
#       <th>2005</th>
#       <th>2006</th>
#       <th>2007</th>
#       <th>2008</th>
#       <th>2009</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>CIDR</th>
#       <td>90.89</td>
#       <td>96.52</td>
#       <td>97.38</td>
#       <td>98.30</td>
#       <td>104.72</td>
#       <td>107.84</td>
#       <td>108.83</td>
#       <td>111.61</td>
#       <td>112.00</td>
#       <td>112.81</td>
#       <td>110.29</td>
#     </tr>
#     <tr>
#       <th>BPE</th>
#       <td>93.64</td>
#       <td>111.20</td>
#       <td>136.58</td>
#       <td>173.01</td>
#       <td>191.00</td>
#       <td>210.56</td>
#       <td>243.08</td>
#       <td>299.23</td>
#       <td>357.00</td>
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib

def plot(factor, title, xlabel, ylabel):
    matplotlib.style.use('ggplot')
    plt.style.use('ggplot')

    fig1 = plt.figure()
    ax1 = fig1.add_subplot(111)
    mean = data_1999_2009_sbi.loc[factor].mean()
    std = data_1999_2009_sbi.loc[factor].std()

    ax1.plot(data_1999_2009_sbi.columns, data_1999_2009_sbi.loc[factor].values, marker='.', ms=10, c='blue')
    ax1.set_xlabel(xlabel)
    ax1.set_ylabel(ylabel)
    ax1.set_title('{0}\nMean:{1} Standard Deviation:{2}'.format(title,
                                                                round(mean, 2),
                                                                round(std, 2)))
    plt.xticks([1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009], rotation=90)
    plt.savefig('Dataset/Bank Data/SBI/{0}.png'.format(factor), bbox_inches='tight')
    plt.show()
% store -r data_1999_2009_sbi

# %%
plot('CIDR', '(Credit+Investment)-Deposit Ratio', 'Years', 'Ratio')

# %%
plot('BPE', 'Business per Employee(in Lakhs)', 'Years', 'Cost')

# %%
plot('CAR', 'Capital Adequacy Ratio', 'Years', 'Ratio')

# %%
plot('CAR-T1', 'Capital Adequacy Ratio Tier-I', 'Years', 'Ratio')

# %%
plot('CAR-T2', 'Capital Adequacy Ratio Tier-II', 'Years', 'Ratio')

# %%
plot('CADR', 'Cash Deposit Ratio', 'Years', 'Ratio')

# %%
plot('COB', 'Cost of Borrowings', 'Years', 'Ratio')

# %%
plot('COD', 'Cost of Deposits', 'Years', 'Ratio')

# %%
plot('COF', 'Cost of Funds', 'Years', 'Ratio')

# %%
plot('CRDR', 'Credit Deposit Ratio', 'Years', 'Ratio')

# %%
plot('IDR', 'Investment Deposit Ratio', 'Years', 'Ratio')

# %%
plot('PPE', 'Profit per Employee(in Lakhs)', 'Years', 'Cost')

# %%
plot('BII-RATIO', 'Ratio of Burden to Interest Income', 'Years', 'Ratio')

# %%
plot('BTA-RATIO', 'Ratio of Burden to Total Assets', 'Years', 'Ratio')

# %%
plot('DTL-RATIO', 'Ratio of Deposits to Total Liabilities', 'Years', 'Ratio')

# %%
plot('IITA-RATIO', 'Ratio of Interest Income cost to Total Assets', 'Years', 'Ratio')

# %%
plot('ICTA-RATIO', 'Ratio of Intermediation Cost to Total Assets', 'Years', 'Ratio')

# %%
plot('INASTI-RATIO', 'Ratio of Investment in Non-approved securities to Total Investments', 'Years', 'Ratio')

# %%
plot('NIMTA-RATIO', 'Ratio of Net Interest Margin to Total Assets', 'Years', 'Ratio')

# %%
plot('NNNA-RATIO', 'Ratio of Net NPA to Net Advances', 'Years', 'Ratio')

# %%
plot('NIITA-RATIO', 'Ratio of Non-interest Income to Total Assets', 'Years', 'Ratio')

# %%
plot('OPTA-RATIO', 'Ratio of Operating Profits to Total Assets', 'Years', 'Ratio')

# %%
plot('PSATA-RATIO', 'Ratio of Priority Sector Advances to Total Advances', 'Years', 'Ratio')

# %%
plot('SATA-RATIO', 'Ratio of Secured Advances to Total Advances', 'Years', 'Ratio')

# %%
plot('TLTA-RATIO', 'Ratio of Term Loans to Total Advances', 'Years', 'Ratio')

# %%
plot('WBIC-RATIO', 'Ratio of Wage Bills to Intermediation Cost', 'Years', 'Ratio')

# %%
plot('WBTE-RATIO', 'Ratio of Wage Bills to Total Expenses', 'Years', 'Ratio')

# %%
plot('WBTI-RATIO', 'Ratio of Wage Bills to Total Income', 'Years', 'Ratio')

# %%
plot('ROAD', 'Return on Advances', 'Years', 'Percentage')

# %%
plot('ROAADJCOF', 'Return on Advances adjusted to Cost of Funds', 'Years', 'Percentage')

# %%
plot('ROA', 'Return on Assets', 'Years', 'Percentage')

# %%
plot('ROE', 'Return on Equity', 'Years', 'Percentage')

# %%
plot('ROIADJCF', 'Return on Investment to Adjusted to Cost of Funds', 'Years', 'Percentage')

# %%
plot('ROI', 'Return on Investments', 'Years', 'Percentage')

# %%
plot('GNPASTA', 'Gross NPAs/Total Assets', 'Years', 'Ratio')

# %%
plot('NNPASTA', 'Net NPAs/Total Assets', 'Years', 'Ratio')
